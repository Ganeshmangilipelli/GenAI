# %%
corpus="""  Hello welcome to my channel
    This is my first video
    I hope you like it
    Subscribe to my channel
    Share this video with your friends
    """
print(corpus)
# Out:
#   Hello welcome to my channel
#     This is my first video
#     I hope you like it
#     Subscribe to my channel
#     Share this video with your friends

# %%
import nltk
from nltk.tokenize import sent_tokenize

# Download the tokenizer data (run once)
nltk.download('punkt')

# Define the text
corpus = """
Hello! My name is Ganesh.
I am learning Natural Language Processing using NLTK.
NLTK is a powerful Python library.
It helps with tokenization, stemming, lemmatization, and more.
"""

# Sentence tokenization
sentences = sent_tokenize(corpus)

print(sentences)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import nltk
#       2 from nltk.tokenize import sent_tokenize
#       3
#       4 # Download the tokenizer data (run once)
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import sys
print(sys.executable)
# Out:
# f:\Udemy_courses\GenAI\venv1\Scripts\python.exe

# %%
# %pip install nltk
# Out:
# ...
#   Using cached nltk-3.10.0-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached tqdm-4.68.4-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached nltk-3.10.0-py3-none-any.whl (1.7 MB)
# ...
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached tqdm-4.68.4-py3-none-any.whl (676 kB)
# ...
#
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------------------------------------- 0/4 [tqdm]
#    ---------- ----------------------------- 1/4 [regex]
#    ---------- ----------------------------- 1/4 [regex]
#    -------------------- ------------------- 2/4 [defusedxml]
#    -------------------- ------------------- 2/4 [defusedxml]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
#    ------------------------------ --------- 3/4 [nltk]
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ganes\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import nltk
from nltk.tokenize import sent_tokenize

# Define the text
corpus = """
Hello! My name is Ganesh.
I am learning Natural Language Processing using NLTK.
NLTK is a powerful Python library.
It helps with tokenization, stemming, lemmatization, and more.
"""

# Sentence tokenization
sentences = sent_tokenize(corpus)

print(sentences)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 13
#       9 It helps with tokenization, stemming, lemmatization, and more.
#      10 """
#      11
#      12 # Sentence tokenization
# ---> 13 sentences = sent_tokenize(corpus)
#      14
#      15 print(sentences)
#
# File f:\Udemy_courses\GenAI\venv1\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# ...

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ganes\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ganes\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

text = "Hello. My name is Ganesh. I am learning NLTK."

documents=((sent_tokenize(text)))
print(documents)
# Out:
# ['Hello.', 'My name is Ganesh.', 'I am learning NLTK.']

# %%
for sent in documents:
  print(sent)
  print()
# Out:
# Hello.
#
# My name is Ganesh.
#
# I am learning NLTK.

# %%
## paragraph to words

from nltk.tokenize import word_tokenize

text = "Hello. My name is Ganesh. I am learning NLTK."

documents=(word_tokenize(text))
print(documents)
# Out:
# ['Hello', '.', 'My', 'name', 'is', 'Ganesh', '.', 'I', 'am', 'learning', 'NLTK', '.']

# %%
from nltk.tokenize import wordpunct_tokenize,sent_tokenize

text = "Hello. My name is Ganesh. I am learning NLTK."

documents=(wordpunct_tokenize(text))
print(documents)
# Out:
# ['Hello', '.', 'My', 'name', 'is', 'Ganesh', '.', 'I', 'am', 'learning', 'NLTK', '.']

# %%
from nltk.tokenize import TreeBankWordTokenizer

text = "Hello. My name is Ganesh. I am learning NLTK."

documents=(treebank_word_tokenize(text))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from nltk.tokenize import TreeBankWordTokenizer
#       2
#       3 text = "Hello. My name is Ganesh. I am learning NLTK."
#       4
#
# ImportError: cannot import name 'TreeBankWordTokenizer' from 'nltk.tokenize' (f:\Udemy_courses\GenAI\venv1\Lib\site-packages\nltk\tokenize\__init__.py)

# %%
from nltk.tokenize import TreebankWordTokenizer

text = "Hello. My name is Ganesh. I am learning NLTK."

tokenizer = TreebankWordTokenizer()
documents = tokenizer.tokenize(text)

print(documents)
# Out:
# ['Hello.', 'My', 'name', 'is', 'Ganesh.', 'I', 'am', 'learning', 'NLTK', '.']
