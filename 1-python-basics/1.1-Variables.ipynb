# %%
a=100
print(a)
# Out:
# 100

# %%
age=32
height=1.75
name="John"
is_student=True
##printing the variables
print("Age:", age)
print("Height:", height)
print("Name:", name)
print("Is student:", is_student)
# Out:
# Age: 32
# Height: 1.75
# Name: John
# Is student: True

# %%
#Naming conventions

#snake_case
#camelCase
#PascalCase
#kebab-case
#train-case
##variable names should not start with a number
##variable names should not contain special characters
##variable names should be descriptive
first_name="John"
last_name="Doe"

# %%
##Invalid variable names
first-name="John" #invalid
first name="John" #invalid
first-name="John" #invalid
first_name="John" #valid

# %%
##understanding variable types
##python is dynamically typed language,type of a variable can be changed at runtime
age =25
height=1.75
name="John"
print(type(age))
print(type(height))
print(type(name))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
##type checking and conversion
age=25
print(type(age))
age_str=str(age)
print(type(age_str))
age="25"
int_age=int(age)
print(type(int_age))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %%
height=1.75
print(type(height))
# Out:
# <class 'float'>

# %%
print(int(height)) #float(int(height))
# Out:
# 1

# %%
##dynamic typing 
variable=10
print(variable,type(variable))
# Out:
# 10 <class 'int'>

# %%
var=10
print(var,type(var))

var="hello"
print(var,type(var))

var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input
age=input("Enter your age:")
print("Your age is:", age,type(age))
# Out:
# Your age is: 34 <class 'str'>

# %%
num1=input("Enter first number:")
num2=input("Enter second number:")
sum=int(num1)+int(num2)
difference=int(num1)-int(num2)
product=int(num1)*int(num2)
quotient=int(num1)/int(num2)
print("Sum:", sum)
print("Difference:", difference)    
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 68
# Difference: -22
# Product: 1035
# Quotient: 0.5111111111111111
