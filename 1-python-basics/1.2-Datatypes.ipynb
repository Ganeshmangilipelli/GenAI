# %%
##Integers example

x = 1
y = 2
z = x + y
type(z)
# Out:
# int

# %%
name = "John"
type(name)
print(name)
# Out:
# John

# %%
##boolean example

is_cool = True
print(is_cool)
type(is_cool)
# Out:
# True
# bool

# %%
bool()
# Out:
# False

# %%
result="hello"+str(55)

# %%
str="hello"
