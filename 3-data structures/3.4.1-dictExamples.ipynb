# %%
## real world examples of dictionary

## example of dictionary for student records

student_records = {
    "student1": {
        "name": "John",
        "age": 20,
        "grade": "A"
    },
    "student2": {
        "name": "Jane",
        "age": 21,
        "grade": "B"
    }
}

print(student_records)

## example of dictionary for employee records

employee_records = {
    "employee1": {
        "name": "John",
        "age": 30,
        "position": "Manager"
    },
    "employee2": {
        "name": "Jane",
        "age": 25,
        "position": "Developer"
    }
}

print(employee_records)
