# %%
import array
arr=array.array('i')
print(arr)
# Out:
# array('i')

# %%
import random

print(random.randint(1,10))
print(random.choice([1,2,3,4,5]))
# Out:
# 2
# 3

# %%
## file and directory acccess
import os
print(os.getcwd())
print(os.listdir())
print(os.path.exists("test.txt"))
print(os.path.isfile("test.txt"))
print(os.path.isdir("test.txt"))
# Out:
# f:\Udemy_courses\GenAI\5-modules
# ['5.1-import.ipynb', '5.2-standardLibrary.ipynb', 'package', 'test.py']
# False
# False
# False

# %%
os.mkdir("test")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 os.mkdir("test")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'test'

# %%
##high level operations on files and collection of files
import shutil
shutil.copy("source.txt","destination.txt")
# Out:
# 'destination.txt'

# %%
##data serialization
import json 
data={"name":"John","age":30,"city":"New York"}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "John", "age": 30, "city": "New York"}
# <class 'str'>
# {'name': 'John', 'age': 30, 'city': 'New York'}
# <class 'dict'>

# %%
##csv 
import csv
with open("example.csv",mode="w",newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["Name","Age","City"])
    writer.writerow(["John",30,"New York"])
    writer.writerow(["Jane",25,"Los Angeles"])
with open("example.csv",mode="r") as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['John', '30', 'New York']
# ['Jane', '25', 'Los Angeles']

# %%
## datetime
from datetime import datetime,timedelta
now=datetime.now()
print(now)
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-07-11 10:32:54.928992
# 2026-07-10 10:32:54.928992

# %%
## time
import time
print(time.time())
print(time.localtime(time.time()))
print(time.asctime(time.localtime(time.time())))
# Out:
# 1783746218.965575
# time.struct_time(tm_year=2026, tm_mon=7, tm_mday=11, tm_hour=10, tm_min=33, tm_sec=38, tm_wday=5, tm_yday=192, tm_isdst=0)
# Sat Jul 11 10:33:38 2026

# %%
## regular expression
import re
pattern=r"hello"
text="hello world"
match=re.search(pattern,text)
print(match)
print(match.group())
print(match.span())
print(match.start())
print(match.end())
# Out:
# <re.Match object; span=(0, 5), match='hello'>
# hello
# (0, 5)
# 0
# 5

# %%
''' python standard libray is extension and provides tools for python developers to write code more efficiently and effectively.
it is a collection of modules and functions that are built-in to the python interpreter.
it is a built-in module in python that provides access to many useful functions and objects.
it is a collection of functions and classes that are built-in to the python interpreter and are available for use in any python program.'''
