# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt,pi
sqrt(4)
print(pi)
print(sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
import numpy as np
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from math import *  
sqrt(4)
print(pi)
print(sqrt(16))
# Out:
# 3.141592653589793
# 4.0

# %%
from package.math import addtition  
addtition(2,3)
# Out:
# 5
