# %%
## creating a nerw directory
import os
new_directory = "package1"
os.mkdir(new_directory)
print('directory created')
# Out:
# directory created

# %%
##listing files and directories
items=os.listdir(".")
print(items)
# Out:
# ['example.bin', 'example.txt', 'example_copy.txt', 'fileoperation.ipynb', 'filepath.ipynb', 'package']

# %%
## joining path
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
## joining path
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# f:\Udemy_courses\GenAI\6-File Handling\folder\file.txt

# %%
path="example.txt"
if os.path.exists(path):
    print(f"file  '{path}'  exists")
else:
    print("file does not exists")
# Out:
# file  'example.txt'  exists

# %%
#checking if a path is file or a directory
import os 
path="example.txt"
print(os.path.isfile(path))
print(os.path.isdir(path))
# Out:
# True
# False

# %%
## getting the absolute path
path="example.txt"
print(os.path.abspath(path))
print(os.path.abspath("."))
# Out:
# f:\Udemy_courses\GenAI\6-File Handling\example.txt
# f:\Udemy_courses\GenAI\6-File Handling
